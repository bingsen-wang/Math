# %% [markdown]
# <a href="https://colab.research.google.com/github/bingsen-wang/Math/blob/main/ChebyshevPolynomial_ThirdKind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1><b>Chebyshev Polynomials of the Third Kind
# </h1></b>
#
# Dr. Bingsen Wang
#
# 11/2/2024
# </center>

# %% [markdown]
# #Python Code

# %%
from numpy import linspace,cos,arccos,pi
from matplotlib import animation,pyplot,cm
pyplot.rcParams.update({'font.family':"sans serif",'animation.html':'jshtml',
                     'mathtext.fontset':'cm'})
def V(x,n):
  return cos((n+.5)*arccos(x))/cos(arccos(x)*.5)

Nf=40
clst = list(cm.tab20.colors) #colors of lines
x = linspace(-1,1,1000)
Vn_lst = [V(x,k+1) for k in range(Nf)]
fig = pyplot.figure(figsize=([9,9]))
ax = fig.add_subplot(111,xlim=(-1,1),ylim=(-3,3))
lines=[ax.plot([],[],lw=1.5,c=clst[i%len(clst)])[0] for i in range(len(Vn_lst))]
def animate(ii):
  # ii=2*Nf-1
  i=ii%Nf
  k=ii//Nf
  if k==0:
    ax.set_title(f"Chebyshev Polynomial of the Second Kind: Order ${i+1}$",size=18)
    lines[i-1].set_data([],[])
    lines[i].set_data(x,Vn_lst[i])
  else:
    if i==0:
      ax.set_title(f"Chebyshev Polynomials of the Second Kind: Orders $1-{Nf}$",size=18)
    [lines[j].set_data(x[:(i+1)*len(x)//Nf],Vn_lst[j][:(i+1)*len(x)//Nf]) for j in range(Nf)]
  return
anim = animation.FuncAnimation(fig, animate, frames=Nf*2, interval=50)
anim.save("chebyshevPolynomials_ThirdKind.mp4", writer=animation.FFMpegWriter(fps=5), dpi = 300)
