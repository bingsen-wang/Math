# %% [markdown]
# <a href="https://colab.research.google.com/github/bingsen-wang/Math/blob/main/ChebyshevPolynomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1><b>Chebyshev Polynomials
# </h1></b>
#
# Dr. Bingsen Wang
#
# 10/28/2024
# </center>

# %% [markdown]
# #Python Code

# %%
from numpy import linspace
from matplotlib import animation,pyplot,cm

def cheb(n,x):
  if n==0:
    return 1
  elif n==1:
    return x
  else:
    return 2*x*cheb(n-1,x)-cheb(n-2,x)

clst = list(cm.tab10.colors) #colors of lines
x,n = linspace(-1,1,500),linspace(1,10,10)
Tn = [cheb(k+1,x) for k in range(len(n))]
fig,ax = pyplot.subplots(figsize=([9,9]))
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)

def animate(i):
  ax.plot(x,Tn[i],lw=2,c=clst[i%len(clst)])
  return
anim = animation.FuncAnimation(fig, animate, frames=len(n), interval=50)
anim.save("chebyshevPolynomials.mp4", writer=animation.FFMpegWriter(fps=1), dpi = 200)
